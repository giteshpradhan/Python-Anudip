# %% [markdown]
# *Write a python program to creat a file and write a line of text into it. Then read the same file and display the content

# %%
file = open("myfile.txt", "w")
file.write("Hello, my friend")
file = open("myfile.txt", "r")
content = file.read()
print(content)
# Out:
# Hello, my friend

# %% [markdown]
# Write a program to append student details into a file without deleting the existing data

# %%
file= open("students.txt", "a")
file.write("Name: Gitesh, Roll No: 101, Course: Python\n")
file=open("students.txt", "r")
print(file.read())
file.close()
# Out:
# Name: Gitesh, Roll No: 101, Course: Python

# %% [markdown]
# Write a program to read all the content of a file and count the number of lines present in it.

# %%
file =open("data.txt","r")
readfile=file.readline()
print(len(readfile))

# %% [markdown]
# Write a program to handle the error when a file does not exist using exception handling.

# %%
try:
   open("data2.txt","r")
   context=file.read()
   file.close()
except FileNotFoundError:
    print("File does not found")
# Out:
# File does not found
