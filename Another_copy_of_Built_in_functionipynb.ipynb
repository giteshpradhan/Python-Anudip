# %% [markdown]
# 1. Find the length of a string
# python

# %%
s = input("Enter a string: ")
print("Length of string:", len(s))
# Out:
# Enter a string: Gitesh
# Length of string: 6

# %% [markdown]
# 2. Display data type of a number

# %%
num = input("Enter a number: ")
print("Data type:", type(eval(num)))
# Out:
# Enter a number: 10
# Data type: <class 'int'>

# %% [markdown]
# 3. Sum of two numbers using type conversion

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("Sum:", a + b)
# Out:
# Enter first number: 12
# Enter second number: 12
# Sum: 24

# %% [markdown]
# 4. Maximum of two numbers

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("Maximum:", max(a, b))
# Out:
# Enter first number: 14
# Enter second number: 5
# Maximum: 14

# %% [markdown]
# 5. String in uppercase

# %%
s = input("Enter a string: ")
print("Uppercase:", s.upper())
# Out:
# Enter a string: gitesh
# Uppercase: GITESH

# %% [markdown]
# 6. First and last character of a string

# %%
s = input("Enter a string: ")
print("First:", s[0], "Last:", s[-1])
# Out:
# Enter a string: Gitesh
# First: G Last: h

# %% [markdown]
# 7. Check if string is empty

# %%
s = input("Enter a string: ")
print("Empty?" , s == "")
# Out:
# Enter a string:
# Empty? True

# %% [markdown]
# 8. Count characters without len()

# %%
s = input("Enter a string: ")
count = 0
for ch in s:
    count += 1
print("Character count:", count)
# Out:
# Enter a string: Gitesh
# Character count: 6

# %% [markdown]
# 9. Reverse a string

# %%
s = input("Enter a string: ")
print("Reversed:", s[::-1])
# Out:
# Enter a string: Gitesh
# Reversed: hsetiG

# %% [markdown]
# 10. Palindrome check

# %%
s = input("Enter a string: ")
print("Palindrome?" , s == s[::-1])
# Out:
# Enter a string: Yash
# Palindrome? False

# %% [markdown]
# 11. Convert to lowercase and uppercase

# %%
s = input("Enter a string: ")
print("Lowercase:", s.lower())
print("Uppercase:", s.upper())
# Out:
# Enter a string: Gitesh
# Lowercase: gitesh
# Uppercase: GITESH

# %% [markdown]
# 12. Remove extra spaces

# %%
s = input("Enter a string: ")
print("Trimmed:", s.strip())
# Out:
# Enter a string: Gitesh
# Trimmed: Gitesh

# %% [markdown]
# 13. Replace a word

# %%
msg = "I love Java"
print (msg.replace("java","python"))
# Out:
# I love Java

# %% [markdown]
# 14. Position of a word

# %%
sentence = input("Enter a sentence: ")
word = input("Enter word: ")
print("Position:", sentence.find(word))
# Out:
# Enter a sentence: I love java
# Enter word: java
# Position: 7

# %% [markdown]
# 15. Split sentence into words

# %%
sentence = input("Enter a sentence: ")
print("Words:", sentence.split())
# Out:
# Enter a sentence: Hello my friends
# Words: ['Hello', 'my', 'friends']

# %% [markdown]
# 16. Username without spaces + count

# %%
username = input("Enter username: ")
cleaned = username.replace(" ", "")
print("Cleaned:", cleaned)
print("Character count:", len(cleaned))
# Out:
# Enter username: Yash
# Cleaned: Yash
# Character count: 4

# %% [markdown]
# 17. Check if email contains

# %%
email = input("Enter email ID: ")
print("Contains '@'?", "@" in email)
# Out:
# Enter email ID: gitesh554@
# Contains '@'? True

# %% [markdown]
# 18. Count vowels in a string

# %%
s = input("Enter a string: ")
vowels = "aeiouAEIOU"
count = 0
for ch in s:
    if ch in vowels:
        count += 1
print("Number of vowels:", count)
# Out:
# Enter a string: Hello my friends how are you
# Number of vowels: 9

# %% [markdown]
# 19. Count words in a sentence

# %%
sentence = input("Enter a sentence: ")
words = sentence.split()
print("Word count:", len(words))
# Out:
# Enter a sentence: How was your anudip cource going
# Word count: 6

# %% [markdown]
# 20. Display each character one by one

# %%
s = input("Enter a string: ")
for ch in s:
    print(ch)
# Out:
# Enter a string: Anudip
# A
# n
# u
# d
# i
# p
